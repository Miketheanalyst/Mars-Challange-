# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchWindowException, WebDriverException

try:
    # Initialize the WebDriver using ChromeDriverManager
    service = ChromeService(executable_path=ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service)

    # Visit the Mars news site
    url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
    driver.get(url)

    # Print the title of the page
    print(driver.title)

except NoSuchWindowException:
    print("The browser window is not available.")
except WebDriverException as e:
    print(f"WebDriverException encountered: {e}")
# Out:
# Mars Temperature Data

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
from bs4 import BeautifulSoup

# Create a Beautiful Soup object
   # Get the page source
html = driver.page_source

    # Create a BeautifulSoup object
soup = BeautifulSoup(html, "html.parser")

# %%
# Extract all rows of data
table_rows=soup.find_all("tr","data-row")
table_rows
# Out:
# [<tr class="data-row">
#  <td>2</td>
#  <td>2012-08-16</td>
#  <td>10</td>
#  <td>155</td>
#  <td>6</td>
#  <td>-75.0</td>
#  <td>739.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>13</td>
#  <td>2012-08-17</td>
#  <td>11</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>24</td>
#  <td>2012-08-18</td>
#  <td>12</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>741.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>35</td>
#  <td>2012-08-19</td>
#  <td>13</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>732.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>46</td>
#  <td>2012-08-20</td>
#  <td>14</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>57</td>
#  <td>2012-08-21</td>
#  <td>15</td>
#  <td>158</td>
#  <td>6</td>
#  <td>-78.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>68</td>
#  <td>2012-08-22</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
empty_list=[]
# Loop through the scraped data to create a list of rows
for row in table_rows:
    row_info=row.find_all("td")
    data_row=[td.text.strip() for td in row_info]
    empty_list.append(data_row)
empty_list
# Out:
# [['2', '2012-08-16', '10', '155', '6', '-75.0', '739.0'],
#  ['13', '2012-08-17', '11', '156', '6', '-76.0', '740.0'],
#  ['24', '2012-08-18', '12', '156', '6', '-76.0', '741.0'],
#  ['35', '2012-08-19', '13', '157', '6', '-74.0', '732.0'],
#  ['46', '2012-08-20', '14', '157', '6', '-74.0', '740.0'],
#  ['57', '2012-08-21', '15', '158', '6', '-78.0', '740.0'],
#  ['68', '2012-08-22', '16', '158', '6', '-77.0', '740.0'],
#  ['79', '2012-08-23', '17', '159', '6', '-76.0', '742.0'],
#  ['112', '2012-08-27', '21', '161', '6', '-74.0', '741.0'],
#  ['114', '2012-08-28', '22', '162', '6', '-74.0', '742.0'],
#  ['123', '2012-08-29', '23', '162', '6', '-75.0', '741.0'],
#  ['134', '2012-08-30', '24', '163', '6', '-75.0', '742.0'],
#  ['145', '2012-08-31', '25', '163', '6', '-75.0', '743.0'],
#  ['156', '2012-09-01', '26', '164', '6', '-76.0', '745.0'],
#  ['163', '2012-09-02', '27', '164', '6', '-75.0', '743.0'],
#  ['170', '2012-09-03', '28', '165', '6', '-75.0', '745.0'],
# ...

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
columns_names=["id","terrestrial_date","sol","ls","month","min_temp","pressure"]
mars_weather_df=pd.DataFrame(empty_list,columns=columns_names)

# %%
# Confirm DataFrame was created successfully
mars_weather_df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %%
# Confirm DataFrame was created successfully
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
mars_weather_df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
# Change data types for data analysis
mars_weather_df["id"] = mars_weather_df["id"].astype(int)
mars_weather_df["terrestrial_date"] = pd.to_datetime(mars_weather_df['terrestrial_date'])
mars_weather_df["sol"] = mars_weather_df["sol"].astype(int)
mars_weather_df["ls"] = mars_weather_df["ls"].astype(int)
mars_weather_df["month"] = mars_weather_df["month"].astype(int)
mars_weather_df["min_temp"] = mars_weather_df["min_temp"].astype(float)
mars_weather_df["pressure"] = mars_weather_df["pressure"].astype(float)

# %%
# Confirm type changes were successful by examining data types again
mars_weather_df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
martian_months = mars_weather_df["month"].value_counts().sort_index()
martian_months
# Out:
# month
# 1     174
# 10    112
# 11    138
# 12    166
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# Name: count, dtype: int64

# %%
# 2. How many Martian days' worth of data are there?
unique_martian_days = mars_weather_df["sol"].nunique()
unique_martian_days
# Out:
# 1867

# %%
# Check the data types of the DataFrame
print(mars_weather_df.dtypes)

# If min_temp is not numeric, convert it to numeric
mars_weather_df['min_temp'] = pd.to_numeric(mars_weather_df['min_temp'], errors='coerce')

# 3. What is the average low temperature by month?
average_min_temp_by_month = mars_weather_df.groupby("month")["min_temp"].mean()
print(average_min_temp_by_month)
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object
# month
# 1    -77.160920
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# Name: min_temp, dtype: float64

# %%
# Plot the average temperature by month
average_min_temp_by_month.plot(kind="bar")
plt.xlabel("Month")
plt.ylabel("Temperature in Celsius")
# Out:
# Text(0, 0.5, 'Temperature in Celsius')

# %%
# Identify the coldest and hottest months in Curiosity's location
min_temp_sorted=average_min_temp_by_month.sort_values()
min_temp_sorted_df=min_temp_sorted.reset_index()

min_temp_sorted_df.columns=["Month","Average Min Temperature"]

min_temp_sorted_df["Month"]=min_temp_sorted_df["Month"].astype(str)

month_order = min_temp_sorted_df["Month"].tolist()
min_temp_sorted_df["Month"] = pd.Categorical(min_temp_sorted_df["Month"], categories=month_order, ordered=True)

plt.bar(min_temp_sorted_df["Month"], min_temp_sorted_df["Average Min Temperature"], width=0.5)

plt.xlabel("Month")
plt.ylabel("Temperature in Celsius")

plt.show()

# %%
# 4. Average pressure by Martian month
# Assuming mars_weather_df is your DataFrame
mars_weather_df['pressure'] = pd.to_numeric(mars_weather_df['pressure'], errors='coerce')

# Now perform the groupby operation
average_monthly_pressure = mars_weather_df.groupby('month')['pressure'].mean()

# Display the result
print(average_monthly_pressure)
# Out:
# month
# 1     862.488506
# 10    887.312500
# 11    857.014493
# 12    842.156627
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
# Plot the average pressure by month
sorted_monthly_pressure=average_monthly_pressure.sort_values()
pressure_df=sorted_monthly_pressure.reset_index()
pressure_df.columns=["Month","Average Atmospheric Pressure"]

pressure_df["Month"] =pressure_df["Month"].astype(str)

pressure_month_order=pressure_df["Month"].tolist()
pressure_df["Month"]=pd.Categorical(pressure_df["Month"],categories=pressure_month_order, ordered=True)

plt.bar(pressure_df["Month"],pressure_df["Average Atmospheric Pressure"],width=0.5)
plt.xlabel("Month")
plt.ylabel("Atmospheric Pressure")

plt.show()

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
plt.plot(mars_weather_df["sol"],mars_weather_df["min_temp"])
plt.xlabel("Number of terrestrial days")
plt.ylabel("Minimum temperature")

plt.show()

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
import os

# Define the directory and file path
directory = "Scraped_data"
file_path = os.path.join(directory, "Mars_weather.csv")

# Create the directory if it does not exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Write the data to a CSV file
mars_weather_df.to_csv(file_path)

# %%
browser.quit()
